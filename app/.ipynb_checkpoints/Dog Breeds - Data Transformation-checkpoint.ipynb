# %%
import pandas as pd

# %%
df1 = pd.read_csv("data//dog_breeds_from_kaggle.csv")
df2 = pd.read_csv("data//dog_breeds_clean.csv")

# %%
df1.head()
# Out:
#                Name       Origin     Type          Unique Feature  \
# 0     Affenpinscher      Germany      Toy        Monkey-like face
# 1      Afghan Hound  Afghanistan    Hound         Long silky coat
# 2  Airedale Terrier      England  Terrier     Largest of terriers
# 3             Akita        Japan  Working          Strong loyalty
# 4  Alaskan Malamute   Alaska USA  Working  Strong pulling ability
#
#    Friendly Rating (1-10)  Life Span    Size Grooming Needs  \
# 0                       7         14   Small           High
# 1                       5         13   Large      Very High
# 2                       8         12  Medium           High
# 3                       6         11   Large       Moderate
# 4                       7         11   Large           High
#
#    Exercise Requirements (hrs/day) Good with Children  \
# 0                              1.5                Yes
# 1                              2.0                 No
# ...

# %%
df2.head()
# Out:
#                name  species_id  \
# 0     Affenpinscher           2
# 1      Afghan Hound           2
# 2         Africanis           2
# 3              Aidi           2
# 4  Airedale Terrier           2
#
#                                          temperament  \
# 0       confident, alert, playful, loyal, courageous
# 1    independent, dignified, aloof, loyal, confident
# 2  intelligent, loyal, alert, adaptable, independent
# 3  alert, protective, independent, loyal, courage...
# 4  confident, intelligent, courageous, alert, ene...
#
#                      origin country_code  \
# 0                   Germany           DE
# 1               Afghanistan           AF
# 2           Southern Africa           ZA
# 3  Atlas Mountains, Morocco           MA
# 4        Yorkshire, England           GB
#
#                                          description breed_group  \
# 0  Small, sturdy toy breed with a distinctive mon...         Toy
# ...

# %%
df = pd.merge(df1, df2, left_on='Name', right_on='name')

# %%
df.shape
# Out:
# (144, 33)

# %%
df1.shape
# Out:
# (159, 15)

# %%
df2.shape
# Out:
# (630, 18)

# %%
df.head()
# Out:
#                Name       Origin     Type          Unique Feature  \
# 0     Affenpinscher      Germany      Toy        Monkey-like face
# 1      Afghan Hound  Afghanistan    Hound         Long silky coat
# 2  Airedale Terrier      England  Terrier     Largest of terriers
# 3             Akita        Japan  Working          Strong loyalty
# 4  Alaskan Malamute   Alaska USA  Working  Strong pulling ability
#
#    Friendly Rating (1-10)  Life Span    Size Grooming Needs  \
# 0                       7         14   Small           High
# 1                       5         13   Large      Very High
# 2                       8         12  Medium           High
# 3                       6         11   Large       Moderate
# 4                       7         11   Large           High
#
#    Exercise Requirements (hrs/day) Good with Children  ...  \
# 0                              1.5                Yes  ...
# 1                              2.0                 No  ...
# ...

# %%
df.columns
# Out:
# Index(['Name', 'Origin', 'Type', 'Unique Feature', 'Friendly Rating (1-10)',
#        'Life Span', 'Size', 'Grooming Needs',
#        'Exercise Requirements (hrs/day)', 'Good with Children',
#        'Intelligence Rating (1-10)', 'Shedding Level', 'Health Issues Risk',
#        'Average Weight (kg)', 'Training Difficulty (1-10)', 'name',
#        'species_id', 'temperament', 'origin', 'country_code', 'description',
#        'breed_group', 'history', 'image', 'weight_min_kg', 'weight_max_kg',
#        'weight_avg_kg', 'height_min_cm', 'height_max_cm', 'height_mid_cm',
#        'life_span_min_years', 'life_span_max_years', 'life_span_mid_years'],
#       dtype='str')
